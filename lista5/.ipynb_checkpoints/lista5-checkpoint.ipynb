# %%
# %pip install pandas
from numba import jit
import numbers
import numpy as np
import math
import matplotlib.pyplot as plt
from scipy.special import logsumexp
import pandas
import random
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\lucas\miniconda3\lib\site-packages (from pandas) (2.8.1)
# ...

# %%
@jit(nopython=True)
def estado_ini(N):
    #Gera um estado inicial aleatório para rede
    s = np.zeros(N,dtype=np.int8)
    for i in range(N):
        s[i] = np.sign(2*np.random.random()-1)
    return s

@jit(nopython=True)
def vizinhos(L,N):
    #Define a tabela de vizinhos 
    viz = np.zeros((N,4),dtype=np.int16)
    for k in range(N):
        viz[k,0]=k+1
        if (k+1) % L == 0: viz[k,0] = k+1-L
        viz[k,1] = k+L 
        if k > (N-L-1): viz[k,1] = k+L-N
        viz[k,2] = k-1 
        if k % L == 0: viz[k,2] = k+L-1
        viz[k,3] = k-L 
        if k < L: viz[k,3] = k+N-L
    return viz

@jit(nopython=True)
def energia(s,viz, N):
    #Calcula a energia da configuração s
    ener = 0 
    for i in range(N):
        h = s[viz[i,0]]+s[viz[i,1]]
        ener -= s[i]*h
    ener = int((ener+2*N)/4)
    return ener

@jit(nopython=True)
def expos(beta):
    ex = np.zeros(5,dtype=np.float32)
    ex[0]=np.exp(8.0*beta)
    ex[1]=np.exp(4.0*beta)
    ex[2]=0.0
    ex[3]=np.exp(-4.0*beta)
    ex[4]=np.exp(-8.0*beta)
    return ex

@jit(nopython=True)
def mcstep(beta,s,viz,ener,mag):
    N = len(s)
    ex = expos(beta)
    for i in range(N):
        h = s[viz[i,0]]+s[viz[i,1]]+s[viz[i,2]]+s[viz[i,3]] # soma dos vizinhos
        de = int(s[i]*h*0.5+2)
        if np.random.random() < ex[de]:
            ener = ener+2*s[i]*h
            mag -= 2*s[i]
            s[i] =- s[i]
    return ener,mag,s

# %%
L = 32
N = L*L
t = 1.5
steps=2000

s = estado_ini(N)
viz = vizinhos(L,N)
ener = energia(s, viz, N)
beta = 1/t
mag = s.sum()

ener_v1 = np.zeros(steps)
mag_v1 = np.zeros(steps)

for i in range(steps):
    ener,mag,s = mcstep(beta,s,viz,ener,mag)
    ener_v1[i] = ener
    mag_v1[i] = mag

# %%
L = 32
N = L*L
t = 1.0
steps = 2000

s = estado_ini(N)
viz = vizinhos(L,N)
ener = energia(s, viz, N)
beta = 1/t
mag = s.sum()

ener_v2 = np.zeros(steps)
mag_v2 = np.zeros(steps)

for i in range(steps):
    ener,mag,s = mcstep(beta,s,viz,ener,mag)
    ener_v2[i] = ener
    mag_v2[i] = mag

# %% [markdown]
# Testando configurações com diferentes temperaturas inicias pude perceber a tendência a um valor médio por parte de cada configuração.

# %%
steps_plot = np.linspace(0,steps-1,steps)

plt.plot(steps_plot, mag_v1, label = 'Mag1', color='blue')
plt.plot(steps_plot, mag_v2, label = 'Mag2', color='black')
plt.plot(steps_plot, ener_v1, label = 'Ener1', color='green')
plt.plot(steps_plot, ener_v2, label = 'Ener2', color='yellow')

plt.xlabel("Passos de Monte Carlo")
plt.ylabel("Energia / Magnetização")
plt.legend()
plt.show()

# %% [markdown]
# Testando com configurações aleatórias

# %%
steps=2000
steps_plot = np.linspace(0,steps-1,steps)

size_test = 3

for i in range(0, size_test):
    L = random.randint(24, 100)
    t = random.uniform(0.4, 3)
    
    N = L*L
    s = estado_ini(N)
    viz = vizinhos(L,N)
    ener = energia(s, viz, N)
    beta = 1/t
    mag = s.sum()

    ener_v = np.zeros(steps)
    mag_v = np.zeros(steps)

    for i in range(steps):
        ener,mag,s = mcstep(beta,s,viz,ener,mag)
        ener_v[i] = ener
        mag_v[i] = mag

    plt.plot(steps_plot, mag_v, label = 'Mag', color='blue')
    plt.plot(steps_plot, ener_v, label = 'Ener', color='green')
    plt.title("L = " + str(L) + ", t = " + str(t))
    plt.xlabel("Passos de Monte Carlo")
    plt.ylabel("Energia / Magnetização")
    plt.legend()
    plt.show()

# %% [markdown]
# Gerando algumas configurações aleatórias, é perceptível como a temperatura maior (no meu caso, mais próxima a 3) gera gráficos com mais variações em seu eixo Y, onde se encontram as variáveis de magnetização e energia. Isto é esperando pois alteram de acordo com a temperatura.
# Por outro lado, com temperaturas menores é perceptível menores variações no gráfico ao decorrer do eixo X, também esperando pelo mesmo motivo.

# %% [markdown]
# Testando no extremo L e t

# %%
steps=2000
steps_plot = np.linspace(0,steps-1,steps)

L = 100
t = 3
N = L*L
s = estado_ini(N)
viz = vizinhos(L,N)
ener = energia(s, viz, N)
beta = 1/t
mag = s.sum()

ener_v = np.zeros(steps)
mag_v = np.zeros(steps)

for i in range(steps):
    ener,mag,s = mcstep(beta,s,viz,ener,mag)
    ener_v[i] = ener
    mag_v[i] = mag

plt.plot(steps_plot, mag_v, label = 'Mag', color='blue')
plt.plot(steps_plot, ener_v, label = 'Ener', color='green')
plt.title("L = " + str(L) + ", t = " + str(t))
plt.xlabel("Passos de Monte Carlo")
plt.ylabel("Energia / Magnetização")
plt.legend()
plt.show()

# %%
steps=2000
steps_plot = np.linspace(0,steps-1,steps)

L = 24
t = 3
N = L*L
s = estado_ini(N)
viz = vizinhos(L,N)
ener = energia(s, viz, N)
beta = 1/t
mag = s.sum()

ener_v = np.zeros(steps)
mag_v = np.zeros(steps)

for i in range(steps):
    ener,mag,s = mcstep(beta,s,viz,ener,mag)
    ener_v[i] = ener
    mag_v[i] = mag

plt.plot(steps_plot, mag_v, label = 'Mag', color='blue')
plt.plot(steps_plot, ener_v, label = 'Ener', color='green')
plt.title("L = " + str(L) + ", t = " + str(t))
plt.xlabel("Passos de Monte Carlo")
plt.ylabel("Energia / Magnetização")
plt.legend()
plt.show()

# %%
steps=2000
steps_plot = np.linspace(0,steps-1,steps)

L = 100
t = 0.4
N = L*L
s = estado_ini(N)
viz = vizinhos(L,N)
ener = energia(s, viz, N)
beta = 1/t
mag = s.sum()

ener_v = np.zeros(steps)
mag_v = np.zeros(steps)

for i in range(steps):
    ener,mag,s = mcstep(beta,s,viz,ener,mag)
    ener_v[i] = ener
    mag_v[i] = mag

plt.plot(steps_plot, mag_v, label = 'Mag', color='blue')
plt.plot(steps_plot, ener_v, label = 'Ener', color='green')
plt.title("L = " + str(L) + ", t = " + str(t))
plt.xlabel("Passos de Monte Carlo")
plt.ylabel("Energia / Magnetização")
plt.legend()
plt.show()

# %%
steps=2000
steps_plot = np.linspace(0,steps-1,steps)

L = 24
t = 0.4
N = L*L
s = estado_ini(N)
viz = vizinhos(L,N)
ener = energia(s, viz, N)
beta = 1/t
mag = s.sum()

ener_v = np.zeros(steps)
mag_v = np.zeros(steps)

for i in range(steps):
    ener,mag,s = mcstep(beta,s,viz,ener,mag)
    ener_v[i] = ener
    mag_v[i] = mag

plt.plot(steps_plot, mag_v, label = 'Mag', color='blue')
plt.plot(steps_plot, ener_v, label = 'Ener', color='green')
plt.title("L = " + str(L) + ", t = " + str(t))
plt.xlabel("Passos de Monte Carlo")
plt.ylabel("Energia / Magnetização")
plt.legend()
plt.show()

# %% [markdown]
# Dados para a tabela

# %%
steps=2000
steps_plot = np.linspace(0,steps-1,steps)

size_test = 3

# for i in range(0, size_test):
temps = np.linspace(0.4, 3, 10)

for t in temps:

    L = 62
    N = L*L

    s = estado_ini(N)
    viz = vizinhos(L,N)
    ener = energia(s, viz, N)
    beta = 1/t
    mag = s.sum()

    ener_v = np.zeros(steps)
    mag_v = np.zeros(steps)

    for i in range(steps):
        ener,mag,s = mcstep(beta,s,viz,ener,mag)
        ener_v[i] = ener
        mag_v[i] = mag

    plt.plot(steps_plot, mag_v, label = 'Mag', color='blue')
    plt.plot(steps_plot, ener_v, label = 'Ener', color='green')
    plt.title("L = " + str(L) + ", t = " + str(t))
    plt.xlabel("Passos de Monte Carlo")
    plt.ylabel("Energia / Magnetização")
    plt.legend()
    plt.show()

# %%
L_size_array = [62]*10
t_array = np.linspace(0.4, 3, 10)
convegence_step_mag = [None]*10
convegence_step_ener = [None]*10

convegence_step_mag[0] = 0
convegence_step_mag[1] = 0
convegence_step_mag[2] = 500
convegence_step_mag[3] = 1250
convegence_step_mag[4] = 1750
convegence_step_mag[5] = None
convegence_step_mag[6] = None
convegence_step_mag[7] = None
convegence_step_mag[8] = None
convegence_step_mag[9] = None

convegence_step_ener[0] = 2
convegence_step_ener[1] = 1800
convegence_step_ener[2] = 1500
convegence_step_ener[3] = 800
convegence_step_ener[4] = 1500
convegence_step_ener[5] = 750
convegence_step_ener[6] = 1800
convegence_step_ener[7] = 125
convegence_step_ener[8] = 10
convegence_step_ener[9] = 0

# %%
data = {'L': L_size_array, 't': t_array, 'Convergence mag': convegence_step_mag, 'Convergence ener': convegence_step_ener }
df = pandas.DataFrame(data=data)
print(df)
# Out:
#     L         t  Convergence mag  Convergence ener
# 0  62  0.400000              0.0                 2
# 1  62  0.688889              0.0              1800
# 2  62  0.977778            500.0              1500
# 3  62  1.266667           1250.0               800
# 4  62  1.555556           1750.0              1500
# 5  62  1.844444              NaN               750
# 6  62  2.133333              NaN              1800
# 7  62  2.422222              NaN               125
# 8  62  2.711111              NaN                10
# 9  62  3.000000              NaN                 0

# %% [markdown]
# Tabela variando apenas a temperatura, vemos que a convergência ocorre nos primeiros passos para magnetização e depois não ocorre até o passo 2000
# Já a energia tende a convergir para um valor médio em temperaturas maiores, de acordo com os testes que realizei.

# %%
steps=2000
steps_plot = np.linspace(0,steps-1,steps)

size_test = 3

Ls = [24, 32, 40, 48, 56, 64, 72, 80, 88, 96]

for L in Ls:
    N = L*L
    t = 1.5
    s = estado_ini(N)
    viz = vizinhos(L,N)
    ener = energia(s, viz, N)
    beta = 1/t
    mag = s.sum()

    ener_v = np.zeros(steps)
    mag_v = np.zeros(steps)

    for i in range(steps):
        ener,mag,s = mcstep(beta,s,viz,ener,mag)
        ener_v[i] = ener
        mag_v[i] = mag

    plt.plot(steps_plot, mag_v, label = 'Mag', color='blue')
    plt.plot(steps_plot, ener_v, label = 'Ener', color='green')
    plt.title("L = " + str(L) + ", t = " + str(t))
    plt.xlabel("Passos de Monte Carlo")
    plt.ylabel("Energia / Magnetização")
    plt.legend()
    plt.show()

# %%
L_size_array = Ls
t_array = [1.5]*10
convegence_step_mag = [None]*10
convegence_step_ener = [None]*10

convegence_step_mag[0] = 300
convegence_step_mag[1] = 900
convegence_step_mag[2] = 600
convegence_step_mag[3] = 1350
convegence_step_mag[4] = 1800
convegence_step_mag[5] = 1150
convegence_step_mag[6] = 1300
convegence_step_mag[7] = None
convegence_step_mag[8] = 1300
convegence_step_mag[9] = 1900

convegence_step_ener[0] = 300
convegence_step_ener[1] = 900
convegence_step_ener[2] = 600
convegence_step_ener[3] = 1350
convegence_step_ener[4] = 250
convegence_step_ener[5] = 350
convegence_step_ener[6] = 500
convegence_step_ener[7] = 1500
convegence_step_ener[8] = 1250
convegence_step_ener[9] = 1800

# %%
data = {'L': L_size_array, 't': t_array, 'Convergence mag': convegence_step_mag, 'Convergence ener': convegence_step_ener }
df = pandas.DataFrame(data=data)
print(df)
# Out:
#     L    t  Convergence mag  Convergence ener
# 0  24  1.5            300.0               300
# 1  32  1.5            900.0               900
# 2  40  1.5            600.0               600
# 3  48  1.5           1350.0              1350
# 4  56  1.5           1800.0               250
# 5  64  1.5           1150.0               350
# 6  72  1.5           1300.0               500
# 7  80  1.5              NaN              1500
# 8  88  1.5           1300.0              1250
# 9  96  1.5           1900.0              1800

# %% [markdown]
# Tabela variando apenas a rede.
# Nesse caso, a convergência de ambos se mostrou acontecer nos passos iniciais em redes menores, enquanto para redes maiores a convergência ocorreu nos passos finais, de modo geral.
